# %%
import pandas as pd
import numpy as np
import os

# %%
#Importando arquivo excel

excel = pd.read_excel('../Conversões/ParaExcel.xlsx')

# %%
#cConvertendo para dataframe 
df = pd.DataFrame(excel)

#Excluindo arquivo intermendiário
caminho = '../Conversões/ParaExcel.xlsx'

if os.path.exists(caminho):
   os.remove(caminho)
else:
   print('Valor não encontrado!')

# %%
df.head()
# Out:
#          Time  Partidas  Vitorias  Empates  Derrotas  Gols_Pro  Gols_Contra  \
# 0   São Paulo        10         9        2         7         8            7
# 1     Naútico        10         7        5         6         7           11
# 2       Sport        10         7        2        12         2           23
# 3  Santa Cruz        10         5        3         5         5            5
#
#    Saldo_Gols  Pontos
# 0           1      29
# 1          -4      26
# 2         -21      23
# 3           0      18

# %%
display(df.info())
display(df.head())
display(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Time         4 non-null      object
#  1   Partidas     4 non-null      int64
#  2   Vitorias     4 non-null      int64
#  3   Empates      4 non-null      int64
#  4   Derrotas     4 non-null      int64
#  5   Gols_Pro     4 non-null      int64
#  6   Gols_Contra  4 non-null      int64
#  7   Saldo_Gols   4 non-null      int64
#  8   Pontos       4 non-null      int64
# dtypes: int64(8), object(1)
# memory usage: 420.0+ bytes
# None
#          Time  Partidas  Vitorias  Empates  Derrotas  Gols_Pro  Gols_Contra  \
# 0   São Paulo        10         9        2         7         8            7
# 1     Naútico        10         7        5         6         7           11
# 2       Sport        10         7        2        12         2           23
# ...

# %%
display(df.head(2))
df.tail(2)
# Out:
#         Time  Partidas  Vitorias  Empates  Derrotas  Gols_Pro  Gols_Contra  \
# 0  São Paulo        10         9        2         7         8            7
# 1    Naútico        10         7        5         6         7           11
#
#    Saldo_Gols  Pontos
# 0           1      29
# 1          -4      26
#          Time  Partidas  Vitorias  Empates  Derrotas  Gols_Pro  Gols_Contra  \
# 2       Sport        10         7        2        12         2           23
# 3  Santa Cruz        10         5        3         5         5            5
#
#    Saldo_Gols  Pontos
# 2         -21      23
# 3           0      18

# %%
#1-Desempenho Geral

desempenho_info = df[['Time', 'Vitorias', 'Pontos', 'Saldo_Gols']].set_index('Time')
desempenho_info
# Out:
#             Vitorias  Pontos  Saldo_Gols
# Time
# São Paulo          9      29           1
# Sport              7      23         -21
# Naútico            7      26          -4
# Santa Cruz         5      18           0

# %%
#2-Time com mais Vitórias

timesComMaisVitorias = df[df['Vitorias'] == df['Vitorias'].max()][['Time', 'Partidas']]
timesComMaisVitorias
# Out:
#         Time  Partidas
# 0  São Paulo        10

# %%
#3-Times com menos vitórias

timesComMenosvitorias = df[df['Vitorias']==df['Vitorias'].min()][['Vitorias','Time']]
timesComMenosvitorias
# Out:
#    Vitorias        Time
# 3         5  Santa Cruz

# %%
b = timesComMaisVitorias
a = b.copy()
a['Partidas'] = 99
display(a)
display(b)
# Out:
#         Time  Partidas
# 0  São Paulo        99
#         Time  Partidas
# 0  São Paulo        10

# %%
#Teste de cópia

dados2 = {
    'Time': ['São Paulo', 'Sport'],
    'Pontos' : [2, 4],
    'Gols' : [3, 4]
}

df2 = pd.DataFrame(dados2)

# %%
df2.head()
# Out:
#         Time  Pontos  Gols
# 0  São Paulo       2     3
# 1      Sport       4     4

# %%
df3 = df2[['Time', 'Gols']]
df3['Gols'] = 10

display(df2)
display(df3)
# Out:
# C:\Users\arcan\AppData\Local\Temp\ipykernel_16700\2919659919.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Gols'] = 10
#         Time  Pontos  Gols
# 0  São Paulo       2     3
# 1      Sport       4     4
#         Time  Gols
# 0  São Paulo    10
# 1      Sport    10

# %%
df.head()
# Out:
#          Time  Partidas  Vitorias  Empates  Derrotas  Gols_Pro  Gols_Contra  \
# 0   São Paulo        10         9        2         7         8            7
# 1       Sport        10         7        2        12         2           23
# 2     Naútico        10         7        5         6         7           11
# 3  Santa Cruz        10         5        3         5         5            5
#
#    Saldo_Gols  Pontos
# 0           1      29
# 1         -21      23
# 2          -4      26
# 3           0      18

# %%
#Distribuição(contagem) de Gols Pro

df.value_counts(['Gols_Pro']).to_frame()
# Out:
#           count
# Gols_Pro
# 2             1
# 5             1
# 7             1
# 8             1

# %%
#Agrupando de Gols Pro
df2 = df.groupby('Time')['Gols_Pro'].sum()
df2.reset_index()
# Out:
#          Time  Gols_Pro
# 0     Naútico         7
# 1  Santa Cruz         5
# 2       Sport         2
# 3   São Paulo         8

# %%
#4- Relação entre colunas Gols Pro e Pontos

correlacao = df['Gols_Pro'].corr(df['Pontos'])
correlacao
# Out:
# np.float64(0.5909368402852788)

# %%
#Correlaçãogols contr e pontos
correlacao2 = df['Gols_Contra'].corr(df['Pontos'])
correlacao2
# Out:
# np.float64(0.03525905902319634)
