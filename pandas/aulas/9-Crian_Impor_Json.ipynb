# %% [markdown]
# # O json é o tipo de arquivo mais comum para API(s)

# %% [markdown]
# ## Import Json
#
# ### Biblioteca padrão apra trabalhos com arquivos Json

# %%
import json

# %%
dadosReceitas = {
    'Receitas' : [
        {
            'Titilo': 'Receita de bolo',
            'TempoPreparo' : '45 min',
            'Porções' : 8,
            'Ingredientes' : [
                {'Ingredientes' : 'Açucar', 'Quantidade': '1 xícaras'},
                {'Ingredientes' : 'Ovos', 'Quantidade': '3 xícaras'},
                {'Ingredientes' : 'Leite', 'Quantidade': '1 xícaras'},
                {'Ingredientes' : 'Farinha', 'Quantidade': '2 xícaras'},
                {'Ingredientes' : 'Manteiga', 'Quantidade': '1/2 xícaras'},
            ]
        },
        {
            'Titilo': 'Salada Ceasar',
            'TempoPreparo' : '20 min',
            'Porções' : 4,
            'Ingredientes' : [
                {'Ingredientes' : 'Alface romana', 'Quantidade': '1 cabeça'},
                {'Ingredientes' : 'Croutons', 'Quantidade': '1 xícaras'},
                {'Ingredientes' : 'Queijo parmesão', 'Quantidade': '1/2 xícaras'},
                {'Ingredientes' : 'Molho ceasar', 'Quantidade': '1/4 xícaras'},
            ]    
        },
        {
            'Titilo': 'Salada Ceasar',
            'TempoPreparo' : '20 min',
            'Porções' : 4,
            'Ingredientes' : [
                {'Ingredientes' : 'Alface romana', 'Quantidade': '1 cabeça'},
                {'Ingredientes' : 'Croutons', 'Quantidade': '1 xícaras'},
                {'Ingredientes' : 'Queijo parmesão', 'Quantidade': '1/2 xícaras'},
                {'Ingredientes' : 'Molho ceasar', 'Quantidade': '1/4 xícaras'},
            ]    
        }
    ]
}

# %%
with open('../dados/Receitas.json', "w", encoding="utf-8") as file:
    json.dump(dadosReceitas, file, ensure_ascii=False, indent=4)
