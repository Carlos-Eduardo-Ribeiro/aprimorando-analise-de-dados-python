# %%
#Questão25

import numpy as py

matriz1 = py.array([[1,2,3],[4,5,6]])
matriz2 = py.array([[7,8,9],[10,11,12]])

matrizResultante = py.dot(matriz1, matriz2.T)
print(matrizResultante)
# Out:
# [[ 50  68]
#  [122 167]]
